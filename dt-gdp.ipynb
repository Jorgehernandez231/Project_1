# %%
import pandas as pd

# 1) Load the two metadata CSVs with their full paths
meta_country = pd.read_csv(
    r"F:/Ironhack/Databases/Metadata_Country_API_NY.GDP.MKTP.KD.ZG_DS2_en_csv_v2_38363.csv"
)
meta_indicator = pd.read_csv(
    r"F:/Ironhack/Databases/Metadata_Indicator_API_NY.GDP.MKTP.KD.ZG_DS2_en_csv_v2_38363.csv"
)

# 2) Load the GDP data, skipping the 4-line preamble
gdp = pd.read_csv(
    r"F:/Ironhack/Databases/API_NY.GDP.MKTP.KD.ZG_DS2_en_csv_v2_38363.csv",
    skiprows=4,
    low_memory=False      # keep this if you're on the default (C) engine
)

# 3) Normalize column names to simplify merges
for df in (gdp, meta_country, meta_indicator):
    df.columns = (
        df.columns
          .str.strip()
          .str.replace(' ', '_')
          .str.lower()
    )

# 4) Merge country metadata then indicator metadata
combined = (
    gdp
    .merge(meta_country,   on="country_code",   how="left")
    .merge(meta_indicator, on="indicator_code", how="left")
)

# 5) Inspect the result
print("Combined shape:", combined.shape)
print(combined.head())
# Out:
# Combined shape: (266, 79)
#                   country_name country_code       indicator_name_x  \
# 0                        Aruba          ABW  GDP growth (annual %)
# 1  Africa Eastern and Southern          AFE  GDP growth (annual %)
# 2                  Afghanistan          AFG  GDP growth (annual %)
# 3   Africa Western and Central          AFW  GDP growth (annual %)
# 4                       Angola          AGO  GDP growth (annual %)
#
#       indicator_code  1960      1961      1962      1963      1964      1965  \
# 0  NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN       NaN       NaN
# 1  NY.GDP.MKTP.KD.ZG   NaN  0.469708  7.868623  5.622472  4.689533  5.159536
# 2  NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN       NaN       NaN
# 3  NY.GDP.MKTP.KD.ZG   NaN  1.869637  3.725941  7.039191  5.364761  4.105616
# 4  NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN       NaN       NaN
#
#    ...  unnamed:_69                                             region  \
# 0  ...          NaN                          Latin America & Caribbean
# 1  ...          NaN                                                NaN
# 2  ...          NaN  Middle East, North Africa, Afghanistan & Pakistan
# 3  ...          NaN                                                NaN
# 4  ...          NaN                                 Sub-Saharan Africa
#
#            incomegroup                                       specialnotes  \
# 0          High income                                                NaN
# 1                  NaN  26 countries, stretching from the Red Sea in t...
# 2           Low income  The reporting period for national accounts dat...
# 3                  NaN  22 countries, stretching from the westernmost ...
# 4  Lower middle income  The World Bank systematically assesses the app...
#
#                      tablename  unnamed:_5       indicator_name_y  \
# 0                        Aruba         NaN  GDP growth (annual %)
# 1  Africa Eastern and Southern         NaN  GDP growth (annual %)
# 2                  Afghanistan         NaN  GDP growth (annual %)
# 3   Africa Western and Central         NaN  GDP growth (annual %)
# 4                       Angola         NaN  GDP growth (annual %)
#
#                                          source_note  \
# 0  Gross domestic product is the total income ear...
# 1  Gross domestic product is the total income ear...
# 2  Gross domestic product is the total income ear...
# 3  Gross domestic product is the total income ear...
# 4  Gross domestic product is the total income ear...
#
#                                  source_organization  unnamed:_4
# 0  Country official statistics, National Statisti...         NaN
# 1  Country official statistics, National Statisti...         NaN
# 2  Country official statistics, National Statisti...         NaN
# 3  Country official statistics, National Statisti...         NaN
# 4  Country official statistics, National Statisti...         NaN
#
# [5 rows x 79 columns]

# %%
combined
# Out:
#                     country_name country_code       indicator_name_x  \
# 0                          Aruba          ABW  GDP growth (annual %)
# 1    Africa Eastern and Southern          AFE  GDP growth (annual %)
# 2                    Afghanistan          AFG  GDP growth (annual %)
# 3     Africa Western and Central          AFW  GDP growth (annual %)
# 4                         Angola          AGO  GDP growth (annual %)
# ..                           ...          ...                    ...
# 261                       Kosovo          XKX  GDP growth (annual %)
# 262                  Yemen, Rep.          YEM  GDP growth (annual %)
# 263                 South Africa          ZAF  GDP growth (annual %)
# 264                       Zambia          ZMB  GDP growth (annual %)
# 265                     Zimbabwe          ZWE  GDP growth (annual %)
#
#         indicator_code  1960      1961      1962      1963       1964  \
# 0    NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN        NaN
# 1    NY.GDP.MKTP.KD.ZG   NaN  0.469708  7.868623  5.622472   4.689533
# 2    NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN        NaN
# 3    NY.GDP.MKTP.KD.ZG   NaN  1.869637  3.725941  7.039191   5.364761
# 4    NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN        NaN
# ..                 ...   ...       ...       ...       ...        ...
# 261  NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN        NaN
# 262  NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN        NaN
# 263  NY.GDP.MKTP.KD.ZG   NaN  3.844734  6.177931  7.373709   7.939609
# 264  NY.GDP.MKTP.KD.ZG   NaN  1.361382 -2.490839  3.272393  12.214048
# 265  NY.GDP.MKTP.KD.ZG   NaN  6.316157  1.434471  6.244345  -1.106172
#
#           1965  ...  unnamed:_69  \
# 0          NaN  ...          NaN
# 1     5.159536  ...          NaN
# 2          NaN  ...          NaN
# 3     4.105616  ...          NaN
# 4          NaN  ...          NaN
# ..         ...  ...          ...
# 261        NaN  ...          NaN
# 262        NaN  ...          NaN
# 263   6.122798  ...          NaN
# 264  16.647456  ...          NaN
# 265   4.910571  ...          NaN
#
#                                                 region          incomegroup  \
# 0                            Latin America & Caribbean          High income
# 1                                                  NaN                  NaN
# 2    Middle East, North Africa, Afghanistan & Pakistan           Low income
# 3                                                  NaN                  NaN
# 4                                   Sub-Saharan Africa  Lower middle income
# ..                                                 ...                  ...
# 261                              Europe & Central Asia  Upper middle income
# 262  Middle East, North Africa, Afghanistan & Pakistan           Low income
# 263                                 Sub-Saharan Africa  Upper middle income
# 264                                 Sub-Saharan Africa  Lower middle income
# 265                                 Sub-Saharan Africa  Lower middle income
#
#                                           specialnotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# 2    The reporting period for national accounts dat...
# 3    22 countries, stretching from the westernmost ...
# 4    The World Bank systematically assesses the app...
# ..                                                 ...
# 261                                                NaN
# 262  The World Bank systematically assesses the app...
# 263  Fiscal year end: March 31; reporting period fo...
# 264  National accounts data were rebased to reflect...
# 265  National Accounts data are reported in Zimbabw...
#
#                        tablename  unnamed:_5       indicator_name_y  \
# 0                          Aruba         NaN  GDP growth (annual %)
# 1    Africa Eastern and Southern         NaN  GDP growth (annual %)
# 2                    Afghanistan         NaN  GDP growth (annual %)
# 3     Africa Western and Central         NaN  GDP growth (annual %)
# 4                         Angola         NaN  GDP growth (annual %)
# ..                           ...         ...                    ...
# 261                       Kosovo         NaN  GDP growth (annual %)
# 262                  Yemen, Rep.         NaN  GDP growth (annual %)
# 263                 South Africa         NaN  GDP growth (annual %)
# 264                       Zambia         NaN  GDP growth (annual %)
# 265                     Zimbabwe         NaN  GDP growth (annual %)
#
#                                            source_note  \
# 0    Gross domestic product is the total income ear...
# 1    Gross domestic product is the total income ear...
# 2    Gross domestic product is the total income ear...
# 3    Gross domestic product is the total income ear...
# 4    Gross domestic product is the total income ear...
# ..                                                 ...
# 261  Gross domestic product is the total income ear...
# 262  Gross domestic product is the total income ear...
# 263  Gross domestic product is the total income ear...
# 264  Gross domestic product is the total income ear...
# 265  Gross domestic product is the total income ear...
#
#                                    source_organization  unnamed:_4
# 0    Country official statistics, National Statisti...         NaN
# 1    Country official statistics, National Statisti...         NaN
# 2    Country official statistics, National Statisti...         NaN
# 3    Country official statistics, National Statisti...         NaN
# 4    Country official statistics, National Statisti...         NaN
# ..                                                 ...         ...
# 261  Country official statistics, National Statisti...         NaN
# 262  Country official statistics, National Statisti...         NaN
# 263  Country official statistics, National Statisti...         NaN
# 264  Country official statistics, National Statisti...         NaN
# 265  Country official statistics, National Statisti...         NaN
#
# [266 rows x 79 columns]

# %%
combined.columns
# Out:
# Index(['country_name', 'country_code', 'indicator_name_x', 'indicator_code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', 'unnamed:_69', 'region', 'incomegroup', 'specialnotes',
#        'tablename', 'unnamed:_5', 'indicator_name_y', 'source_note',
#        'source_organization', 'unnamed:_4'],
#       dtype='object')

# %%
brazil_rows = combined[ combined['country_name'] == 'Brazil' ]
brazil_rows[['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971']].sum().median()
# Out:
# 6.650000000000009
